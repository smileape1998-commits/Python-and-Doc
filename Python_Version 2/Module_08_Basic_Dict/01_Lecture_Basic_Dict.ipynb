# %% [markdown]
# # Module 8: Basic Dict (พจนานุกรมเบื้องต้น)
#
# โมดูลนี้เน้นการจัดการและประมวลผลข้อมูลโครงสร้างประเภท พจนานุกรม (Dictionary หรือ dict) ในภาษา Python ซึ่งเป็นโครงสร้างข้อมูลประเภทคู่อันดับ คีย์-ค่า (Key-Value Pairs) สำหรับใช้ในการค้นหา อัปเดต และจัดการข้อมูลที่มีประสิทธิภาพสูง

# %% [markdown]
# ## 8.1 Dict: Key-Value Pairs (คู่อันดับคีย์และค่า)
#
# ### การเปรียบเทียบ list กับ dict
# - **list:** เก็บข้อมูลเป็นรายการเรียงจากซ้ายไปขวา ใช้จำนวนเต็ม (Index: 0, 1, 2, ...) เป็นตัวระบุตำแหน่งในการเข้าถึงข้อมูลใน list เช่น `x = ["MO", "TU", "WE", "TH", "FR", "SA", "SU"]` ดึง `x[2]` ได้ `"WE"`
# - **dict:** เก็บข้อมูลเป็นคู่ ๆ `key: value` ใช้ `key` เป็นตัวระบุ `value` ที่ต้องการใน dict (`key` เป็นได้ทั้ง `int`, `float`, `str`, ...)

# %% [markdown]
# ### ตัวอย่าง 8.1.1: การเปรียบเทียบการใช้งาน List และ Dict

# %%
# การใช้ list
x = ["MO", "TU", "WE", "TH", "FR", "SA", "SU"]
print("x[2] =", x[2])
print("x[4] =", x[4])
print("x[-1] =", x[-1])

# การใช้ dict
d = {"MO":"จ", "TU":"อ", "WE":"พ", "TH":"พฤ", "FR":"ศ", "SA":"ส", "SU":"อา"}
print('d["WE"] =', d["WE"])
print('d["TH"] =', d["TH"])
print('d["SA"] =', d["SA"])

# %% [markdown]
# ### dict เหมือน mapping function (คีย์ห้ามซ้ำ ค่าซ้ำได้)
# พจนานุกรมทำหน้าที่เหมือนฟังก์ชันจับคู่ (Mapping function):
# - **keys ห้ามซ้ำกัน** (เปรียบเหมือน Domain)
# - **values ซ้ำกันได้** (เปรียบเหมือน Range)

# %% [markdown]
# ### ตัวอย่าง 8.1.2: dict จับคู่รหัสนิสิตกับเกรด

# %%
grade = {
    "6130186221": "A",
    "6230221221": "A",
    "6231009821": "B",
    "6230543921": "C",
    "6230431521": "B",
    "6230276821": "A"
}

print('เกรดของ 6130186221 คือ:', grade["6130186221"])
print('เกรดของ 6230543921 คือ:', grade["6230543921"])

# %% [markdown]
# ### การเข้าถึงข้อมูลด้วย key และข้อควรระวังเรื่อง KeyError
# - การส่ง `key` ให้ `dict` จะได้ `value` ออกมา เช่น `v = grade["6231010621"]`
# - **ถ้าใช้คีย์ที่ไม่มีอยู่ใน dict จะเกิดความผิดพลาด (`KeyError`)**
# - มีแต่การส่ง `key` แล้วได้ `value` **ไม่มีแบบส่ง `value` แล้วได้ `key`**

# %% [markdown]
# ### ตัวอย่าง 8.1.3: โปรแกรมค้นหาเกรดจากรหัสนิสิต

# %%
grade = {

# TODO

# %% [markdown]
# ### แบบฝึกหัด 8-1 ข้อที่ 1
#
# จงสร้างตัวแปรชื่อ `d236` เป็นดิคมี key, value 3 คู่ คือ `"TWO"`, `"THREE"` และ `"SIX"` เป็นคีย์ มีค่าที่คู่กันคือ `"สอง"`, `"สาม"` และ `"หก"` ตามลำดับ (เขียนการสร้างตัวแปรแค่บรรทัดเดียว)

# %%
d236 = {"TWO": "สอง", "THREE": "สาม", "SIX": "หก"}
print(d236)

# %% [markdown]
# ### แบบฝึกหัด 8-1 ข้อที่ 2
#
# โปรแกรมนี้มีดิคชื่อ `color` ที่ตั้งค่าให้เรียบร้อยแล้ว จากนั้นรับชื่อย่อวันจากอินพุต เพื่อแสดงสีประจำวันที่รับมา จงเติมคำสั่งเพื่อให้ทำงานตามที่ต้องการ

# %%
color = {
    "SU": "Red",
    "MO": "Yellow",
    "TU": "Pink",
    "WE": "Green",
    "TH": "Orange",
    "FR": "Blue",
    "SA": "Purple"
}
day = input()
print(color[day])

# %% [markdown]
# ### แบบฝึกหัด 8-1 ข้อที่ 3
#
# โปรแกรมนี้มีตัวแปร `student1` เป็นดิคเก็บรายละเอียดของนักเรียนคนหนึ่ง จากนั้นไปอ่านรายละเอียด (ด้วยฟังก์ชัน `read_data` ที่ไม่ได้เปิดเผยรายละเอียด) ของนักเรียนอีกคนเก็บใน `student2` (ซึ่งจัดเก็บในรูปแบบเดียวกับ `student1`) จงเขียนคำสั่งแสดงปีเกิดของ `student2`

# %%
# สมมติฟังก์ชัน read_data()
def read_data():
    return {"Name": "Somchai", "Birthdate": [15, "May", 2002]}

student2 = read_data()
print(student2["Birthdate"][2])

# %% [markdown]
# ---
#
# ## 8.2 Modifying Dict Content (การเพิ่มและการเปลี่ยน value ใน dict)
#
# ### การเพิ่มและการเปลี่ยน value ใน dict
# การกำหนดค่าให้คีย์ด้วยไวยากรณ์ `dict[key] = value` มีการทำงาน 2 กรณี:
# 1. **การเพิ่มคู่อันดับใหม่:** หาก `key` นั้นยังไม่มีอยู่ใน `dict` จะเป็นการสร้างคู่อันดับใหม่ทันที
# 2. **การเปลี่ยนค่าเดิม:** หาก `key` นั้นมีอยู่แล้วใน `dict` จะเป็นการเปลี่ยน `value` เดิมเป็นค่าใหม่

# %% [markdown]
# ### ตัวอย่าง 8.2.1: การรับค่าเกรดนิสิตใส่ dict (เพิ่มและเปลี่ยนค่า)

# %%
grade = {}  # dict ว่าง
n = int(input())

# TODO

print(grade)

# %% [markdown]
# ### ตัวอย่าง 8.2.2: การนับผลโหวตด้วย Dict (เทียบกับการใช้ List)
# การใช้นับผลโหวตให้ผู้สมัครด้วย `dict` ช่วยให้โค้ดกระชับขึ้นเมื่อเทียบกับ `list` ที่ต้องใช้ `.index()` ในการค้นหาตำแหน่งดัชนี

# %%
# การนับผลโหวตด้วย dict
names = ["Mario", "Luigi", "Peach", "Daisy"]
votes = {}

# TODO

    print(n, "-->", votes[n])

# %% [markdown]
# ### แบบฝึกหัด 8-2 ข้อที่ 1
#
# จงสร้างตัวแปรชื่อ `count_alpha` เป็นดิกที่มี key เป็นตัวอักษรภาษาอังกฤษทั้งใหญ่และเล็กทุกตัวอักษร ส่วน value ให้เป็น 0 หมด

# %%
count_alpha = {}
alpha = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

# TODO

print("จำนวนคีย์ใน count_alpha:", len(count_alpha))

# %% [markdown]
# ### แบบฝึกหัด 8-2 ข้อที่ 2
#
# มีดิกชื่อ `number_of_students` อยู่แล้วตัวหนึ่ง จัดเก็บข้อมูลในรูปแบบ `{รหัสวิชา: จำนวนนิสิตที่ลงทะเบียน}` โดยรหัสวิชาเป็นสตริง จงเขียนคำสั่งเพิ่มจำนวนนิสิตที่ลงทะเบียนให้กับวิชา 2110101 อีก 28 คน และตั้งให้วิชา 2301107 มีนิสิตลงทะเบียน 824 คน

# %%
# สมมติดิก number_of_students
number_of_students = {"2110101": 100, "2110102": 50}

number_of_students["2110101"] += 28
number_of_students["2301107"] = 824

print(number_of_students)

# %% [markdown]
# ### แบบฝึกหัด 8-2 ข้อที่ 3
#
# โปรแกรมนี้มีตัวแปร `student1` เป็นดิกเก็บรายละเอียดของนักเรียนคนหนึ่ง จงเขียนฟังก์ชัน `read_data()` มีหน้าที่อ่านข้อมูลจากอินพุตประกอบด้วย เลขประจำตัว, ชื่อ-สกุล, วัน, เดือน, ปีเกิด (คั่นด้วย comma และช่องว่าง) มาเก็บในดิกที่มีรูปแบบเดียวกับ `student1` แล้วคืนเป็นผลของฟังก์ชัน เช่น อินพุตเป็น `4230000021, Natalie P., 9, 6, 1981` จะได้ผลจาก `read_data()` เป็น `{"ID": "4230000021", "Name": "Natalie P.", "Birthdate": [9, 6, 1981]}`

# %%
def read_data():
    x = input().split(", ")
    r = {}
    r["ID"] = x[0]
    r["Name"] = x[1]
    r["Birthdate"] = [int(x[2]), int(x[3]), int(x[4])]
    return r

# %% [markdown]
# ### แบบฝึกหัด 8-2 ข้อที่ 4
#
# จงเขียนโปรแกรมอ่านจากอินพุตบรรทัดเดียวเป็นรายการของชื่อย่อจังหวัด อังกฤษกับไทย คั่นด้วยช่องว่าง เช่น `BKK กทม CMI ชม` เพื่อนำมาสร้างเป็นดิกชื่อ `abbr = {"BKK": "กทม", "CMI": "ชม", "กทม": "BKK", "ชม": "CMI"}`

# %%
x = input().split()
abbr = {}

# TODO

print(abbr)

# %% [markdown]
# ### แบบฝึกหัด 8-2 ข้อที่ 6
#
# บรรทัดแรกของอินพุตคือรายการของรหัสสินค้า ตามด้วยบรรทัดต่อ ๆ ไปจนถึง `end` คือรายการการประมูลสินค้า แต่ละบรรทัดประกอบด้วย รหัสผู้ประมูล รหัสสินค้า ราคาประมูล เราต้องการสร้างดิกชื่อ `bid = {รหัสสินค้า: [รหัสผู้ประมูลสูงสุด, ราคาประมูลสูงสุด]}` คือ มีรหัสสินค้าเป็นคีย์ ส่วนค่าเป็นลิสต์สองช่องเก็บรหัสผู้ประมูลกับราคาประมูลสูงสุด เช่น `bid = {'P001': ['U102', 120], 'P002': ['U101', 150], 'P102': ["", 0]}`
#
# โปรแกรมนี้มีคำสั่งอ่านรหัสสินค้าทั้งหมดมาสร้างดิก `bid` ที่มีทุกค่าเป็น `["", 0]` คือยังไม่มีใครประมูลเลย จงเขียนคำสั่งอ่านข้อมูลการประมูลเพื่อสร้าง `bid` ให้ได้ตามที่ต้องการ

# %%
prods = input().split()
bid = {}

# TODO

print(bid)

# %% [markdown]
# ---
#
# ## 8.3 for k in a_dict (การวนลูปอ่านข้อมูลในพจนานุกรม)
#
# ### การวนลูปอ่าน key ใน dict
# เมื่อใช้คำสั่ง `for e in d:` บนตัวแปรพจนานุกรม `d` ตัวแปร `e` จะรับค่า **คีย์ (key)** ของพจนานุกรมออกมาทีละตัวในแต่ละรอบของการวนลูป แล้วนำคีย์ไปดึง value ด้วย `d[e]`

# %% [markdown]
# ### ตัวอย่าง 8.3.1: การหาค่าเฉลี่ยผลโหวตด้วย `for name in votes:`

# %%
def average_votes(votes):
    # TODO
    pass

d = {"Mario": 3, "Luigi": 4, "Peach": 3, "Daisy": 1}
print("คีย์ทั้งหมดใน d:")
for e in d:
    print(e)

print("ค่าเฉลี่ยผลโหวต:", average_votes(d))

# %% [markdown]
# ### ตัวอย่าง 8.3.2: การค้นหาคีย์กับการเข้าถึงด้วย `gpa[ID]` โดยตรง
# การค้นหาข้อมูลจากคีย์ไม่จำเป็นต้องวนลูปตรวจสอบ `for k in gpa: if k == ID:` เพราะเราสามารถเข้าถึงข้อมูลด้วยคีย์ได้โดยตรงด้วย `gpa[ID]` ในบรรทัดเดียว

# %%
gpa = {
    "6130186221": 3.15,
    "6230221221": 2.85,
    "6231009821": 2.90,
    "6230543921": 3.20,
    "6230431521": 3.35,
    "6230276821": 3.42
}

ID = "6231009821"
# ดึงค่าโดยตรงใน 1 บรรทัด
print(f"GPA ของ {ID} คือ: {gpa[ID]}")

# %% [markdown]
# ### แบบฝึกหัด 8-3 ข้อที่ 1
#
# จงเขียนฟังก์ชัน `get_countries(capital_city, s)` รับ `capital_city` เป็นดิกเก็บข้อมูลในรูปแบบ `{ชื่อประเทศ: ชื่อเมืองหลวง}` และ `s` เป็นสตริง ฟังก์ชันนี้คืนลิสต์ของชื่อประเทศที่ขึ้นต้นด้วยค่าที่เก็บใน `s` โดยลิสต์ที่คืนเรียงชื่อประเทศจากน้อยไปมากตามพจนานุกรม

# %%
def get_countries(capital_city, s):
    # TODO
    pass

capitals = {"Thailand": "Bangkok", "Japan": "Tokyo", "Taiwan": "Taipei"}
print(get_countries(capitals, "Tai")) # ['Taiwan', 'Thailand']

# %% [markdown]
# ### แบบฝึกหัด 8-3 ข้อที่ 2
#
# จงเขียนฟังก์ชัน `get_courseIDs(number_of_students, k)` รับดิก `number_of_students` ที่เก็บข้อมูลในรูปแบบ `{รหัสวิชา: จำนวนนิสิตที่ลงทะเบียน}` กับ `k` ที่เป็นจำนวนเต็ม ฟังก์ชันนี้คืนลิสต์ของรหัสวิชาต่าง ๆ ที่มีจำนวนผู้ลงทะเบียนเรียนตั้งแต่ `k` คนขึ้นไป โดยให้เรียงรหัสวิชาในลิสต์ที่คืนจากน้อยไปมาก

# %%
def get_courseIDs(number_of_students, k):
    # TODO
    pass

students = {"2110101": 120, "2110102": 80, "2110201": 150}
print(get_courseIDs(students, 100)) # ['2110101', '2110201']

# %% [markdown]
# ### แบบฝึกหัด 8-3 ข้อที่ 3
#
# จงเขียนฟังก์ชัน `add_all(points, blacklist, extra)` รับดิก `points` ที่เก็บข้อมูลในรูปแบบ `{รหัสสมาชิก: จำนวนแต้มสะสม}`, `blacklist` เป็นลิสต์เก็บรหัสสมาชิก กับ `extra` เป็นจำนวนแต้ม ฟังก์ชันนี้จะเพิ่มแต้มเป็นจำนวน `extra` ในดิก `points` ให้กับสมาชิกทุกรายที่มีรหัสไม่ปรากฏใน `blacklist` ฟังก์ชันนี้ไม่คืนอะไรเลย เพราะจะปรับข้อมูลใน `points`

# %%
def add_all(points, blacklist, extra):
    # TODO
    pass

pts = {"M01": 10, "M02": 20, "M03": 30}
add_all(pts, ["M02"], 5)
print(pts) # {'M01': 15, 'M02': 20, 'M03': 35}

# %% [markdown]
# ---
#
# ## 8.4 Checking Key Existence in a Dict (`if key in dict` หรือ `if key not in dict`)
#
# ### การตรวจสอบการมีอยู่ของคีย์ใน dict
# - การใช้ `if key in dict:` ช่วยตรวจสอบว่าคีย์มีอยู่ในพจนานุกรมหรือไม่ เพื่อป้องกันการเกิด `KeyError`
# - ในทางกลับกัน สามารถใช้ `if key not in dict:` เพื่อตรวจสอบว่ายังไม่มีคีย์นั้นอยู่ในพจนานุกรม

# %% [markdown]
# ### ตัวอย่าง 8.4.1: การนับคะแนนโหวตด้วย `if key in dict` / `else`

# %%
votes = {}
x = input()

# TODO

    print(name, "-->", votes[name])

# %% [markdown]
# ### แบบฝึกหัด 8-4 ข้อที่ 1
#
# `p1` และ `p2` เป็นดิกเก็บคะแนนของนักเรียนที่เรียนวิชา 1 และ 2 ตามลำดับในรูปแบบ `{เลขประจำตัว: คะแนน}` จงเขียนฟังก์ชัน `take_both(st_id, p1, p2)` เพื่อหาว่านักเรียนที่มีเลขประจำตัว `st_id` เรียนทั้งสองวิชาหรือไม่

# %%
def take_both(st_id, p1, p2):
    # TODO
    pass

p1 = {"S01": 80, "S02": 75}
p2 = {"S02": 90, "S03": 85}
print(take_both("S02", p1, p2)) # True
print(take_both("S01", p1, p2)) # False

# %% [markdown]
# ### แบบฝึกหัด 8-4 ข้อที่ 2
#
# `p1` และ `p2` เป็นดิกเก็บคะแนนของนักเรียนที่เรียนวิชา 1 และ 2 ตามลำดับในรูปแบบ `{เลขประจำตัว: คะแนน}` จงเขียนฟังก์ชัน `both(p1, p2)` เพื่อคืนลิสต์ที่เก็บเลขประจำตัวนักเรียนเรียนทั้งสองวิชา โดยเรียงลำดับเลขประจำตัวนักเรียนในลิสต์จากน้อยไปมากด้วย

# %%
def both(p1, p2):
    # TODO
    pass

p1 = {"S03": 80, "S01": 75, "S02": 60}
p2 = {"S02": 90, "S03": 85, "S04": 70}
print(both(p1, p2)) # ['S02', 'S03']

# %% [markdown]
# ### แบบฝึกหัด 8-4 ข้อที่ 3
#
# สตริง DNA เป็นสตริงที่มีตัวอักขระแค่ A, T, G และ C เท่านั้น จงเขียนฟังก์ชัน `count_bases(dna)` คืนดิกในรูปแบบ `{เบส: จำนวน}` เช่น `count_bases("AAAATTTGG")` ได้ `{"A":4, "T":3, "G":2, "C":0}`

# %%
def count_bases(dna):
    # TODO
    pass

print(count_bases("AAAATTTGG")) # {'A': 4, 'T': 3, 'G': 2, 'C': 0}

# %% [markdown]
# ### แบบฝึกหัด 8-4 ข้อที่ 4
#
# จงเขียนฟังก์ชัน `count_chars(text)` ที่นับว่าใน `text` มีอักขระอะไรเท่าไรบ้าง (โดยให้ตัวอักษรเล็กเหมือนใหญ่ เช่น `count_chars("ABCabcZ")` ได้ดิก `{'A': 2, 'B': 2, 'C': 2, 'Z': 1}` เป็นผลลัพธ์

# %%
def count_chars(text):
    # TODO
    pass

print(count_chars("ABCabcZ")) # {'A': 2, 'B': 2, 'C': 2, 'Z': 1}

# %% [markdown]
# ### แบบฝึกหัด 8-4 ข้อที่ 5
#
# `income1` และ `income2` เป็นดิกในรูปแบบ `{รหัสสาขาร้าน: รายได้}` ซึ่งเก็บรายรับของร้านอาหารสาขาต่าง ๆ จงเขียนฟังก์ชัน `merge(income1, income2)` ที่คืนดิกใหม่ในรูปแบบเดียวกัน แต่เก็บข้อมูลรวมจากทั้งสองดิกที่รับมา เช่น `income1 = {"P100":100, "P200":200}` และ `income2 = {"P200":300, "P300":90}` `merge` กันแล้วจะได้ดิกใหม่ `{"P100":100, "P200":500, "P300":90}`

# %%
def merge(income1, income2):
    # TODO
    pass

inc1 = {"P100": 100, "P200": 200}
inc2 = {"P200": 300, "P300": 90}
print(merge(inc1, inc2)) # {'P100': 100, 'P200': 500, 'P300': 90}

# %% [markdown]
# ### แบบฝึกหัด 8-4 ข้อที่ 6
#
# จงเขียนโปรแกรมอ่านบรรทัดแรกของอินพุตเป็นรายการของรหัสสินค้า บรรทัดที่สองเป็นรายการของราคา (มีจำนวนข้อมูลเท่ากับของบรรทัดแรก โดยสินค้าชิ้นที่ตำแหน่ง i ก็มีราคาที่ตำแหน่ง i) และอ่านบรรทัดถัด ๆ มา (จบด้วย `end`) ที่เป็นรหัสสินค้าที่ต้องการให้แสดงราคา ถ้าหาไม่พบให้แสดง `Not found` จากตัวอย่างจะแสดง `35.0`, `Not found` และ `50.0` บรรทัดละราคา (หรือข้อความ)

# %%
pids = input().split()
p = input().split()
prices = {}

# TODO

# %% [markdown]
# ### แบบฝึกหัด 8-4 ข้อที่ 7
#
# ข้อมูลที่อ่านจากอินพุตเป็นบรรทัด ๆ ไปจนถึง `end` คือรายการการประมูลสินค้า แต่ละบรรทัดประกอบด้วย รหัสผู้ประมูล รหัสสินค้า ราคาประมูล เราต้องการสร้างดิกชื่อ `bid = {รหัสสินค้า: [รหัสผู้ประมูลสูงสุด, ราคาประมูลสูงสุด]}` คือ มีรหัสสินค้าเป็นคีย์ ส่วนค่าเป็นลิสต์สองช่องเก็บรหัสผู้ประมูลกับราคาประมูลสูงสุด เช่น `bid = {'P001': ['U102', 120], 'P002': ['U101', 150]}` จงเขียนคำสั่งอ่านข้อมูลการประมูลเพื่อสร้าง `bid` ให้ได้ตามที่ต้องการ

# %%
bid = {}
x = input().split()

# TODO

print(bid)
