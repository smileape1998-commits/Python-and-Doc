# %% [markdown]
# # Lab Exercises: Module 08 - Basic Dict
#
# แบบฝึกหัดทบทวนการใช้งาน Dictionary คู่อันดับ Key-Value การสลับคีย์และค่า การค้นหาข้อมูลสองทาง การนับความถี่และการจัดเรียง และการคำนวณยอดขาย

# %% [markdown]
# ## 08-01: สลับ key กับ value (Reverse Dict & Find Keys)
#
# จงเขียนฟังก์ชัน `reverse(d)` ที่รับ `d` เป็น dict ที่ไม่มี value ซ้ำกันเลย มาสร้างและคืน dict ใหม่ที่มี key: value กลับกันกับ `d`
# และเขียนอีกฟังก์ชัน `keys(d, v)` ที่คืนลิสต์ของคีย์ต่าง ๆ ใน `d` ที่ value มีค่าเป็น `v`
#
# **ข้อมูลนำเข้า:** คำสั่งภาษา Python ที่ใช้ทดสอบการทำงานของฟังก์ชัน
# **ข้อมูลส่งออก:** ผลที่ได้จากการสั่งทำงานคำสั่งที่ได้รับ
#
# | input (จากแป้นพิมพ์) | output (ทางจอภาพ) |
# | --- | --- |
# | `print(reverse({3:"A", 2:"B"}) == {"A":3, "B":2})` | `True` |
# | `print(keys({3:33, 4:33, 5:55, 2:33}, 33))` | `[3, 4, 2]` |
# | `print(keys({3:33, 4:33, 5:55, 2:33}, 9999))` | `[]` |

# %%
# 08-01: สลับ key กับ value
def reverse(d):
    # TODO
    pass

def keys(d, v):
    # TODO
    pass

# %% [markdown]
# ## 08-02: ชื่อจริง - ชื่อเล่น (อีกแล้ว)
#
# จงเขียนโปรแกรมอ่านรายการชื่อเล่นกับชื่อจริง (กำหนดให้ไม่มีชื่อจริงซ้ำกันเลย และก็ไม่มีชื่อเล่นซ้ำกันด้วย) จากนั้นรับสตริง ถ้าเป็นชื่อจริงก็แสดงชื่อเล่น ถ้าเป็นชื่อเล่นก็แสดงชื่อจริง ถ้าไม่เป็นทั้งชื่อจริงและชื่อเล่น ก็แสดงคำว่า `Not found`
#
# **ข้อมูลนำเข้า:**
# - บรรทัดแรกเป็นจำนวนเต็ม `N`
# - อีก `N` บรรทัดตามมาเป็นชื่อจริงและชื่อเล่นคั่นด้วยช่องว่าง
# - บรรทัดที่ `N+2` เป็นจำนวนเต็ม `M`
# - อีก `M` บรรทัดตามมา ถ้าเป็นชื่อจริงก็คือถามชื่อเล่น ถ้าเป็นชื่อเล่นก็คือถามชื่อจริง
#
# **ข้อมูลส่งออก:** `M` บรรทัด แสดงชื่อเล่นหรือชื่อจริงที่คู่กับชื่อจริงหรือชื่อเล่นที่ป้อนเข้ามา บรรทัดละชื่อ ถ้าไม่เป็นชื่อจากข้อมูลนำเข้า ก็แสดง `Not found`
#
# | input (จากแป้นพิมพ์) | output (ทางจอภาพ) |
# | --- | --- |
# | `10`<br>`Robert Dick`<br>`William Bill`<br>`James Jim`<br>`John Jack`<br>`Margaret Peggy`<br>`Edward Ed`<br>`Sarah Sally`<br>`Andrew Andy`<br>`Anthony Tony`<br>`Deborah Debbie`<br>`4`<br>`John`<br>`Jim`<br>`Don`<br>`Debbie` | `Jack`<br>`James`<br>`Not found`<br>`Deborah` |

# %%
# 08-02: ชื่อจริง - ชื่อเล่น (อีกแล้ว)
n = int(input())
mapping = {}

# TODO

        print("Not found")

# %% [markdown]
# ## 08-03: การนับตัวอักษร (Char Frequency & Sort)
#
# จงเขียนโปรแกรมรับสตริง เพื่อนับว่ามีตัวอักษรภาษาอังกฤษอะไรบ้าง และมีกี่ตัว (ให้ตัวเล็กเหมือนตัวใหญ่)
#
# **ข้อมูลนำเข้า:** บรรทัดเดียวเป็นสตริง
# **ข้อมูลส่งออก:** รายการของตัวอักษรที่มีในสตริงที่รับมา ตามด้วยจำนวนตัวที่นับได้ บรรทัดละตัว เรียงตามจำนวนตัวอักษรที่นับได้จากมากมาน้อย ถ้าเท่ากันให้เรียงตามตัวอักษรตามลำดับพจนานุกรม
#
# **ข้อแนะนำ:**
# สมมติเรามีลิสต์ `x = [[2, "b"], [3, "f"], [4, "x"], [2, "a"]]`
# แปลงลิสต์ `x` เป็น `[[-2, "b"], [-3, "f"], [-4, "x"], [-2, "a"]]`
# นำไปเรียงจากน้อยไปมากได้ `[[-4, "x"], [-3, "f"], [-2, "a"], [-2, "b"]]`
# ถ้าเราไม่ดูเครื่องหมายลบ ก็เสมือนเป็นการเรียงข้อมูลใน `x` โดยเรียงจากมากมาน้อยตามตัวแรก และเรียงตามพจนานุกรมตามตัวหลัง `[[4, "x"], [3, "f"], [2, "a"], [2, "b"]]`
#
# | input (จากแป้นพิมพ์) | output (ทางจอภาพ) |
# | --- | --- |
# | `AaBbbbbbbCcDddd` | `b -> 7`<br>`d -> 4`<br>`a -> 2`<br>`c -> 2` |

# %%
# 08-03: การนับตัวอักษร
s = input().strip()
counts = {}

# TODO

    print(f"{ch} -> {cnt}")

# %% [markdown]
# ## 08-04: ยอดขายไอศกรีม (Ice Cream Sales & Top Sellers)
#
# จงเขียนโปรแกรมอ่านราคาไอศกรีมต่าง ๆ ตามด้วยการขายสินค้าต่าง ๆ ในร้าน เพื่อหาและแสดงยอดขายรวมของไอศกรีม และไอศกรีมชนิดที่มียอดขายสูงสุด
#
# **ข้อมูลนำเข้า:**
# - บรรทัดแรกเป็นจำนวนเต็ม `N`
# - `N` บรรทัดต่อมาเป็นข้อมูลราคาขายของไอศกรีม ประกอบด้วย ชื่อไอศกรีม ตามด้วยราคา (จำนวนจริง) คั่นด้วยช่องว่าง
# - บรรทัดที่ `N+2` เป็นจำนวนเต็ม `M`
# - `M` บรรทัดต่อมาเป็นรายการขายสินค้า ประกอบด้วย ชื่อสินค้า ตามด้วยจำนวนที่ขายได้ คั่นด้วยช่องว่าง
#
# **ข้อมูลส่งออก:**
# - ถ้าขายไอศกรีมไม่ได้เลย ให้แสดงข้อความว่า `No ice cream sales`
# - ถ้ามีการขายไอศกรีม ให้หาและแสดงยอดขายรวมของไอศกรีมในบรรทัดหนึ่ง และตามด้วยรายการของชื่อไอศกรีมที่มียอดขายสูงสุดอีกบรรทัดหนึ่ง ถ้ามีหลายชื่อให้แสดงชื่อเรียงตามพจนานุกรม
#
# | input (จากแป้นพิมพ์) | output (ทางจอภาพ) |
# | --- | --- |
# | `5`<br>`Magnum 50`<br>`Cornetto 25`<br>`PaddlePop 15`<br>`AsianDelight 20`<br>`Calippo 15`<br>`3`<br>`Cookie 20`<br>`MamaTomYum 3`<br>`MangoSheet 10` | `No ice cream sales` |
# | `5`<br>`Magnum 50`<br>`Cornetto 25`<br>`PaddlePop 15`<br>`AsianDelight 20`<br>`Calippo 15`<br>`6`<br>`Magnum 5`<br>`Magnum 5`<br>`Cookie 20`<br>`MamaTomYum 3`<br>`Cornetto 20`<br>`AsianDelight 1` | `Total ice cream sales: 1020.0`<br>`Top sales: Cornetto, Magnum` |

# %%
# 08-04: ยอดขายไอศกรีม
n = int(input())
prices = {}

# TODO

    print("Top sales:", ", ".join(top_items))
