# %% [markdown]
# ---
#
# ## 3.5 if Statement (คำสั่ง if)
#
# ### ตัวอย่าง: คำนวณจำนวนวันในรอบปี (ปีอธิกสุรทิน / Leap Year)
#
# - ให้ `y` เก็บเลขปี ค.ศ.
# - เดือนกุมภาพันธ์มี 29 วัน (ปีนั้นมี 366 วัน) ก็ต่อเมื่อ:
#   - `y` หารด้วย 400 ลงตัว หรือ
#   - `y` หารด้วย 4 ลงตัว แต่ต้องหารด้วย 100 ไม่ลงตัว
#   - เช่น ปี 2004, 2000 (ปี 2100 ไม่เข้าเงื่อนไข)

# %%
# ตัวอย่าง 3.5.1: คำนวณจำนวนวันในรอบปี (Leap Year)
y = int(input())
days_in_year = 365

# TODO

print(days_in_year)

# %% [markdown]
# ### ตัวอย่าง: โปรแกรมซื้อสินค้า 4 ชิ้น (ชิ้นที่ถูกที่สุดได้ฟรี)
#
# รับราคาสินค้า 4 ชิ้น `p1, p2, p3, p4` จากผู้ใช้ หาชิ้นที่ราคาถูกที่สุด (`min_p`) แล้วคำนวณราคารวมทั้งหมดหลังหักส่วนลดสินค้าถูกที่สุดออก

# %%
# ตัวอย่าง 3.5.2: ซื้อสินค้า 4 ชิ้น ฟรีชิ้นที่ถูกที่สุด
p1 = int(input())
min_p = p1
p2 = int(input())

# TODO

print("Total =", p1 + p2 + p3 + p4 - min_p)

# %% [markdown]
# ### แบบฝึกหัด 3-5 ข้อที่ 1
#
# เขียนโปรแกรมตามผังงานข้างล่างนี้
#
# ![แบบฝึกหัด 3-5 ข้อที่ 1](https://www.cp.eng.chula.ac.th/~somchai/python101/images/ex03_05_01.png)

# %%
# แบบฝึกหัด 3-5 ข้อที่ 1: เขียนโปรแกรมตามผังงาน
a = -5
b = 1

# TODO

print(a, b)

# %% [markdown]
# ### แบบฝึกหัด 3-5 ข้อที่ 2
#
# เขียนโปรแกรมตามผังงานข้างล่างนี้
#
# ![แบบฝึกหัด 3-5 ข้อที่ 2](https://www.cp.eng.chula.ac.th/~somchai/python101/images/ex03_05_02.png)

# %%
# แบบฝึกหัด 3-5 ข้อที่ 2: เขียนโปรแกรมตามผังงาน
a = -12
b = 1

# TODO

print(a, b)

# %% [markdown]
# ### แบบฝึกหัด 3-5 ข้อที่ 3
#
# มีตัวแปร `t` เก็บสตริงอยู่แล้ว โดยที่ `t` มีตัวอักษรภายใน 5 ตัว จงแสดงจำนวนตัวใน `t` ที่เป็นสระ (นับทั้งตัวเล็กและตัวใหญ่) เช่น `"Annie"` มีสระ 3 ตัว

# %%
# แบบฝึกหัด 3-5 ข้อที่ 3: นับจำนวนสระในสตริง 5 ตัวอักษร
t = "Annie"
c = 0

# TODO

print(c)

# %% [markdown]
# ### แบบฝึกหัด 3-5 ข้อที่ 1
#
# เขียนโปรแกรมตามผังงานข้างล่างนี้
#
# ![แบบฝึกหัด 3-5 ข้อที่ 1](https://www.cp.eng.chula.ac.th/~somchai/python101/images/ex03_05_01.png)

# %%
# แบบฝึกหัด 3-5 ข้อที่ 1: เขียนโปรแกรมตามผังงาน
a = -5
b = 1

# TODO

print(a, b)

# %% [markdown]
# ### แบบฝึกหัด 3-5 ข้อที่ 2
#
# เขียนโปรแกรมตามผังงานข้างล่างนี้
#
# ![แบบฝึกหัด 3-5 ข้อที่ 2](https://www.cp.eng.chula.ac.th/~somchai/python101/images/ex03_05_02.png)

# %%
# แบบฝึกหัด 3-5 ข้อที่ 2: เขียนโปรแกรมตามผังงาน
a = -12
b = 1

# TODO

print(a, b)

# %% [markdown]
# ### แบบฝึกหัด 3-5 ข้อที่ 3
#
# มีตัวแปร `t` เก็บสตริงอยู่แล้ว โดยที่ `t` มีตัวอักษรภายใน 5 ตัว จงแสดงจำนวนตัวใน `t` ที่เป็นสระ (นับทั้งตัวเล็กและตัวใหญ่) เช่น `"Annie"` มีสระ 3 ตัว

# %%
# แบบฝึกหัด 3-5 ข้อที่ 3: นับจำนวนสระในสตริง 5 ตัวอักษร
t = "Annie"
c = 0

# TODO

print(c)

# %% [markdown]
# ### แบบฝึกหัด 3-5 ข้อที่ 1
#
# เขียนโปรแกรมตามผังงานข้างล่างนี้
#
# ![แบบฝึกหัด 3-5 ข้อที่ 1](https://www.cp.eng.chula.ac.th/~somchai/python101/images/ex03_05_01.png)

# %%
# แบบฝึกหัด 3-5 ข้อที่ 1: เขียนโปรแกรมตามผังงาน
a = -5
b = 1

# TODO

print(a, b)

# %% [markdown]
# ### แบบฝึกหัด 3-5 ข้อที่ 2
#
# เขียนโปรแกรมตามผังงานข้างล่างนี้
#
# ![แบบฝึกหัด 3-5 ข้อที่ 2](https://www.cp.eng.chula.ac.th/~somchai/python101/images/ex03_05_02.png)

# %%
# แบบฝึกหัด 3-5 ข้อที่ 2: เขียนโปรแกรมตามผังงาน
a = -12
b = 1

# TODO

print(a, b)

# %% [markdown]
# ### แบบฝึกหัด 3-5 ข้อที่ 3
#
# มีตัวแปร `t` เก็บสตริงอยู่แล้ว โดยที่ `t` มีตัวอักษรภายใน 5 ตัว จงแสดงจำนวนตัวใน `t` ที่เป็นสระ (นับทั้งตัวเล็กและตัวใหญ่) เช่น `"Annie"` มีสระ 3 ตัว

# %%
# แบบฝึกหัด 3-5 ข้อที่ 3: นับจำนวนสระในสตริง 5 ตัวอักษร
t = "Annie"
c = 0

# TODO

print(c)
