# %% [markdown]
# ---
#
# ## 3.2 Relational operators (ตัวดำเนินการเปรียบเทียบ)
#
# ### นิพจน์บูลีน: กำหนดเงื่อนไข
#
# ![นิพจน์บูลีน กำหนดเงื่อนไข](images/boolean_expressions.png)
#
# - ได้ผลลัพธ์เป็น `True` หรือ `False`
# - ใช้เครื่องหมาย `<` `>` `<=` `>=` `!=` `==` เพื่อเปรียบเทียบว่า `<` `>` `≤` `≥` `≠` `เท่ากัน`
# - เชื่อมการเปรียบเทียบได้ด้วย `and`, `or`
# - กลับผลการเปรียบเทียบได้ด้วย `not`
# - ถ้ามีทั้ง `and`, `or`, `not` จะทำ `not` ก่อน แล้วทำ `and` แล้วทำ `or`

# %%
# ตัวอย่างการใช้ and, or, not กำหนดเงื่อนไขเกี่ยวกับเดือน
m = 4

# TODO: เขียนโค้ดประมวลผล (Live Code) ที่นี่

    print('ลงท้ายด้วย "คม"')

# %% [markdown]
# ### ตัวอย่างการใช้นิพจน์เงื่อนไขในรูปแบบต่างๆ
#
# ![ตัวอย่างนิพจน์เงื่อนไข](images/relational_operators_examples.png)

# %%
# ตัวอย่างการใช้นิพจน์เงื่อนไข
x = 10
m = 5
y = 2024
student_id = "6431234521"
tel_no = "021234567"

# TODO: เขียนโค้ดประมวลผล (Live Code) ที่นี่

    print("เป็นโทรศัพท์ใน กทม")

# %% [markdown]
# ### แบบฝึกหัด 3-2
#
# ![แบบฝึกหัด 3-2 ข้อ 3 และ 4](images/lab_3_2_ex3_4.png)

# %%
# แบบฝึกหัด 3-2 ข้อที่ 3
# แสดงผลของการเปรียบเทียบว่า m เป็นจำนวนเต็มบวกคี่ที่หารด้วย 3 ลงตัวหรือไม่
m = 9
print(m > 0 and m % 2 != 0 and m % 3 == 0)

# %%
# แบบฝึกหัด 3-2 ข้อที่ 4
# แสดงผลของการเปรียบเทียบว่า url เก็บชื่อเว็บไซต์ที่ลงท้ายด้วย .com หรือ .th หรือไม่
url = "https://www.google.com"
print(url.endswith('.com') or url.endswith('.th'))
