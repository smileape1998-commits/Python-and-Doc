# %% [markdown]
# # Lab Exercises: Module 07 - String Processing
#
# แบบฝึกหัดทบทวนการประมวลผลสตริง การจัดการรูปแบบข้อความ การตรวจสอบเงื่อนไข และการอ่าน/เขียนไฟล์ข้อมูล

# %% [markdown]
# ## 07-01: เอกพจน์พหูพจน์ (Singular to Plural)
#
# รูปของคำนามในภาษาอังกฤษมีทั้งแบบเอกพจน์และพหูพจน์ การเขียนคำนามในรูปพหูพจน์จากรูปเอกพจน์มีกฎการเขียนแบบง่ายๆ (ไม่ครอบคลุมทุกกรณี) ดังนี้
# - ถ้าเป็นคำนามที่ลงท้าย `s`, `x` หรือ `ch` ทำเป็นพหูพจน์ได้ด้วยการเติม `es` ต่อท้าย (เช่น `box` $\rightarrow$ `boxes`, `witch` $\rightarrow$ `witches` เป็นต้น)
# - ถ้าลงท้ายด้วย `y` แต่ตัวอักษรก่อน `y` ไม่ใช่สระ, ให้เปลี่ยน `y` เป็น `i` แล้วเติม `es` ต่อท้าย (เช่น `fly` $\rightarrow$ `flies`, `memory` $\rightarrow$ `memories` เป็นต้น)
# - ถ้าไม่ตรงกับกฎสองข้อข้างบนนี้, ให้ต่อท้ายด้วย `s` เลย (เช่น `computer` $\rightarrow$ `computers`, `boy` $\rightarrow$ `boys` เป็นต้น)
#
# **ข้อมูลนำเข้า:** คำนามภาษาอังกฤษ 1 คำ ในรูปเอกพจน์
# **ข้อมูลส่งออก:** คำนามภาษาอังกฤษที่รับมาในรูปพหูพจน์
#
# | input | output |
# | --- | --- |
# | `box` | `boxes` |
# | `fly` | `flies` |
# | `boy` | `boys` |

# %%
# 07-01: เอกพจน์พหูพจน์
w = input().strip()
vowels = "aeiouAEIOU"

# TODO

    print(w + "s")

# %% [markdown]
# ## 07-02: ตัวพิมพ์หลังอูฐ (camelCase)
#
# `camelCase` เป็นรูปแบบการเขียนวลีที่ไม่มีเครื่องหมายวรรคตอน โดยเปลี่ยนคำแรกเป็นตัวเล็กหมด ส่วนคำที่เหลือเขียนแบบ Capitalization คือตัวแรกของคำเป็นตัวใหญ่ ตัวอื่นเล็กหมด แล้วก็นำทุกคำมาเขียนติดกัน (ตัวเลขคงไว้เหมือนเดิม) เช่น `Power of "love" 555` ก็เขียนเป็น `powerOfLove555`
#
# จงเขียนโปรแกรมที่รับวลีภาษาอังกฤษที่มีตัวอักษรอังกฤษตัวเล็ก ตัวใหญ่ ตัวเลข สัญลักษณ์พิเศษ และเครื่องหมายวรรคตอนต่างๆ จากนั้นขจัดสัญลักษณ์พิเศษ และเครื่องหมายวรรคตอนต่างๆ ออกให้หมด แล้วเปลี่ยนเป็น `camelCase` เพื่อแสดงทางจอภาพ
#
# **ข้อมูลนำเข้า:** สตริงหนึ่งบรรทัด
# **ข้อมูลส่งออก:** `camelCase` ของสตริงที่รับเข้ามา
#
# | input (จากแป้นพิมพ์) | output (ทางจอภาพ) |
# | --- | --- |
# | `"True" or "False"` | `trueOrFalse` |
# | `My number is 02-000-0000` | `myNumberIs020000000` |
# | `OK OK OK` | `okOkOk` |

# %%
# 07-02: ตัวพิมพ์หลังอูฐ (camelCase)
s = input().strip()

# TODO

    print("")

# %% [markdown]
# ## 07-05: น้อยสุด-มากสุด-เฉลี่ย (Min Max Average by Academic Year)
#
# จงเขียนโปรแกรมหาคะแนนน้อยสุด มากสุด และคะแนนเฉลี่ยของกลุ่มนิสิตในแฟ้มที่เลือกมาเฉพาะนิสิตที่เริ่มเข้าศึกษาในปี พ.ศ. ที่กำหนดให้
#
# **ข้อมูลนำเข้า:** หนึ่งบรรทัดมีชื่อแฟ้มและปีเริ่มเข้าศึกษาของนิสิตในแฟ้มที่นำมาวิเคราะห์
# **ข้อมูลส่งออก:** คะแนนน้อยสุด คะแนนมากสุด และคะแนนเฉลี่ย ในกรณีที่ไม่มีข้อมูลให้วิเคราะห์ ให้แสดงคำว่า `No data`
#
# **ตัวอย่างข้อมูลภายในแฟ้ม `data.txt`:**
# ```text
# 6230012121 90.0
# 6130351221 80.0
# 6231027921 80.0
# 5830548121 65.5
# 6031087221 79.9
# 6230550321 70.0
# 6230432721 60.0
# 6230215221 50.0
# 6130518321 70.0
# ```
#
# | input (จากแป้นพิมพ์) | output (ทางจอภาพ) |
# | --- | --- |
# | `data.txt 2562` | `50.0 90.0 70.0` |
# | `data.txt 2561` | `70.0 80.0 75.0` |
# | `data.txt 2560` | `79.9 79.9 79.9` |
# | `data.txt 2559` | `No data` |

# %%
# 07-05: น้อยสุด-มากสุด-เฉลี่ย
filename, year_str = input().split()
target_yy = year_str[-2:]  # สองหลักสุดท้ายของปี พ.ศ.

# TODO

    print(f"{min(scores)} {max(scores)} {sum(scores)/len(scores)}")

# %% [markdown]
# ## 07-07: รหัสผ่าน (Password Strength Checker)
#
# รหัสผ่าน (password) ที่ดีต้องมีลักษณะหลายอย่างที่ทำให้การเดารหัสผ่านทำได้ยาก ลักษณะสำคัญบางประการของรหัสผ่านที่ดี มีดังนี้ (พิจารณาเฉพาะตัวอักษรภาษาอังกฤษเท่านั้น):
# 1. ต้องมีอักขระอย่างน้อย 8 ตัว
# 2. ต้องมีทั้งตัวอักษรภาษาอังกฤษตัวใหญ่ ตัวเล็ก ตัวเลข และสัญลักษณ์อื่น ๆ
# 3. ต้องไม่มีอักขระ 4 ตัวใดที่ติดกันซ้ำกัน (เช่น `aaaa`)
# 4. ต้องไม่มีอักขระ 4 ตัวใดที่ติดกันเป็นลำดับตัวเลข ทั้งเพิ่มและลด เช่น `0123`, `2345`, `7890`, `0987`, ...
# 5. ต้องไม่มีอักขระ 4 ตัวใดที่ติดกันเป็นลำดับตัวอักษร ทั้งเพิ่มและลด เช่น `abcd`, `wXYZ`, `ZYxW`, ...
# 6. ต้องไม่มีอักขระ 4 ตัวใดที่ติดกันเป็นลำดับของปุ่มที่ติดกันบนแป้นพิมพ์ ทางซ้ายไปขวา หรือขวามาซ้าย เช่น `ASDF`, `qwer`, `REWq`, `!@#$`, ... พิจารณาเฉพาะลำดับปุ่มที่ติดกันแนวนอน
#
# **ข้อมูลนำเข้า:** รหัสผ่านเป็นสตริงหนึ่งบรรทัด
# **ข้อมูลส่งออก:** รายการข้อความระบุลักษณะสำคัญที่ขาดของรหัสผ่าน (ตามลำดับจากบนลงล่าง อย่างละบรรทัด):
# - ถ้าไม่มีลักษณะข้อที่ 1 ให้แสดง: `Less than 8 characters`
# - ถ้าไม่มีลักษณะข้อที่ 2 เรื่องตัวเล็ก ให้แสดง: `No lowercase letters`
# - ถ้าไม่มีลักษณะข้อที่ 2 เรื่องตัวใหญ่ ให้แสดง: `No uppercase letters`
# - ถ้าไม่มีลักษณะข้อที่ 2 เรื่องตัวเลข ให้แสดง: `No numbers`
# - ถ้าไม่มีลักษณะข้อที่ 2 เรื่องสัญลักษณ์ ให้แสดง: `No symbols`
# - ถ้าไม่มีลักษณะข้อที่ 3 ให้แสดง: `Character repetition`
# - ถ้าไม่มีลักษณะข้อที่ 4 ให้แสดง: `Number sequence`
# - ถ้าไม่มีลักษณะข้อที่ 5 ให้แสดง: `Letter sequence`
# - ถ้าไม่มีลักษณะข้อที่ 6 ให้แสดง: `Keyboard pattern`
# - ถ้าครบถ้วนทุกลักษณะ ให้แสดง: `OK`

# %%
# 07-07: รหัสผ่าน
pwd = input().strip()
errors = []

# TODO

        print(err)
