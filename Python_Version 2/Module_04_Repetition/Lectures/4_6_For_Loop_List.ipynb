# %% [markdown]
# ---
#
# ## 4.6 for e in list (การวนซ้ำในลิสต์)
#
# ### อธิบายแนวคิด (Concept Explanation)
# คำสั่ง `for e in my_list:` ใช้เพื่อดึงสมาชิกแต่ละตัวในลิสต์ออกมาทำงานตามลำดับตั้งแต่ตัวแรกจนถึงตัวสุดท้าย ทำให้เขียนโค้ดสั้น กระชับ และลดความผิดพลาดเรื่องดัชนีเกินขอบเขต (IndexError)

# %% [markdown]
# ### ตัวอย่าง: คัดกรองเฉพาะจำนวนคู่จากลิสต์
#
# **คำอธิบายโจทย์:**
# วนลูปตรวจสอบสมาชิกในลิสต์ `numbers` แล้วนำเฉพาะเลขคู่มาเก็บใน `even_numbers`
#
# * **ข้อมูลนำเข้า (Input):** ลิสต์ตัวเลข `numbers = [12, 7, 9, 20, 15, 30]`
# * **ข้อมูลส่งออก (Output):** ลิสต์เลขคู่ `[12, 20, 30]`

# %%
# ตัวอย่าง: คัดกรองเฉพาะจำนวนคู่จากลิสต์ของตัวเลข
numbers = [12, 7, 9, 20, 15, 30]
even_numbers = []

# TODO

print("เลขคู่ในลิสต์:", even_numbers)

# %% [markdown]
# ### ตัวอย่าง 4.6.1: วนลูปในช่วงสมาชิกที่ต้องการด้วย Slicing
#
# **คำอธิบายโจทย์:**
# วนลูปเฉพาะสมาชิกตรงกลางของลิสต์ โดยใช้ `x[2:-2]` ตัด 2 ตัวแรกและ 2 ตัวท้ายออก
#
# * **ข้อมูลนำเข้า (Input):** กำหนดลิสต์ `x = [1, 3, 4, 5, 7, 8]`
# * **ข้อมูลส่งออก (Output):** สมาชิก `4` และ `5` ทีละบรรทัด

# %%
# ตัวอย่าง 4.6.1: วนลูปในช่วงสมาชิกที่ต้องการโดยใช้ Slicing
x = [1, 3, 4, 5, 7, 8]

# TODO

# %% [markdown]
# ### ตัวอย่าง 4.6.2: อ่านและแสดงรหัสสินค้าจาก input
#
# **คำอธิบายโจทย์:**
# รับรหัสสินค้าที่คั่นด้วยช่องว่างในบรรทัดเดียว แล้วใช้ `.split()` แปลงเป็นลิสต์ เพื่อแสดงรหัสสินค้าทีละบรรทัด
#
# * **ข้อมูลที่ต้องป้อน (Input):** รหัสสินค้าคั่นด้วยช่องว่าง เช่น `P01 P02 P03`
# * **ข้อมูลส่งออก (Output):** รหัสสินค้าแต่ละตัวแยกบรรทัด
#
# | ตัวอย่าง Input | ตัวอย่าง Output |
# |---|---|
# | `P01 P02 P03` | `P01`<br>`P02`<br>`P03` |

# %%
# ตัวอย่าง 4.6.2: อ่านรายการรหัสสินค้าและแสดงทีละบรรทัด
prod_ids = input().split()

# TODO

# %% [markdown]
# ### ตัวอย่าง 4.6.3: แสดงรายการสินค้าจากขวาไปซ้าย (Reverse List)
#
# **คำอธิบายโจทย์:**
# รับข้อมูลในรูปแบบ `หมวดหมู่: รหัสสินค้า1 รหัสสินค้า2 ...` แล้วแยกเอาเฉพาะรหัสสินค้ามาแสดงผลย้อนกลับจากขวาไปซ้าย
#
# * **ข้อมูลที่ต้องป้อน (Input):** ข้อความ เช่น `fruits: apple banana orange`
# * **ข้อมูลส่งออก (Output):** รายการสินค้าย้อนกลับ (`orange`, `banana`, `apple`) ทีละบรรทัด
#
# | ตัวอย่าง Input | ตัวอย่าง Output |
# |---|---|
# | `fruits: apple banana orange` | `orange`<br>`banana`<br>`apple` |

# %%
# ตัวอย่าง 4.6.3: แสดงเฉพาะรหัสสินค้าย้อนกลับจากขวาไปซ้าย
x = input().split(":")
prod_ids = x[1].split()

# TODO

# %% [markdown]
# ### ตัวอย่าง 4.6.4: นับจำนวนสมาชิกที่ตรงกับค่า a ในลิสต์ x
#
# **คำอธิบายโจทย์:**
# - บรรทัดที่ 1 รับรายการข้อความคั่นด้วยช่องว่างแปลงเป็นลิสต์ `x`
# - บรรทัดที่ 2 รับคำค้นหา `a`
# - นับว่ามีคำว่า `a` ปรากฏอยู่ในลิสต์ `x` ทั้งหมดกี่ครั้ง
#
# * **ข้อมูลที่ต้องป้อน (Input):**
#   * บรรทัด 1: ชุดข้อความ เช่น `cat dog cat bird cat`
#   * บรรทัด 2: คำค้นหา เช่น `cat`
# * **ข้อมูลส่งออก (Output):**
#   * จำนวนครั้งที่พบ (เช่น `3`)
#
# | ตัวอย่าง Input | ตัวอย่าง Output |
# |---|---|
# | `cat dog cat bird cat`<br>`cat` | `3` |
# | `10 20 30`<br>`50` | `0` |

# %%
# ตัวอย่าง 4.6.4: นับจำนวนครั้งที่พบค่า a ในลิสต์ x
x = input().split()
a = input()
c = 0

# TODO

print(c)
