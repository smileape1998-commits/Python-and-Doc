# %% [markdown]
# ---
#
# ## 4.2 while (การวนซ้ำด้วยคำสั่ง while)
#
# ### อธิบายแนวคิด (Concept Explanation)
# คำสั่ง `while` จะตรวจสอบเงื่อนไขก่อนเริ่มทำงานเสมอ หากเงื่อนไขเป็นจริง จะทำงานตามคำสั่งภายในบล็อกย่อหน้า เหมาะสำหรับกรณีที่ไม่ทราบจำนวนรอบการทำงานซ้ำที่แน่นอนล่วงหน้า ขึ้นอยู่กับเงื่อนไขในขณะประมวลผล
#
# ### รูปแบบไวยากรณ์
# ```python
# while เงื่อนไข:
#     คำสั่งที่ต้องการทำซ้ำ
# ```

# %% [markdown]
# ### ตัวอย่าง 4.2.1: การหาค่าน้อยที่สุดจากข้อมูล n จำนวน
#
# **คำอธิบายโจทย์:**
# รับจำนวนเต็ม `n` จากนั้นรับตัวเลขเข้ามาอีก `n` บรรทัด แล้วหาตัวเลขที่มีค่าน้อยที่สุด (`min_x`)
#
# * **📥 ข้อมูลที่ต้องป้อน (Input):**
#   * บรรทัดที่ 1: จำนวนเต็ม `n` (เช่น `4`)
#   * บรรทัดถัดไป `n` บรรทัด: ตัวเลขจำนวนเต็มแต่ละตัว (เช่น `25`, `12`, `38`, `7`)
# * **📤 ข้อมูลส่งออก (Output):**
#   * ค่าน้อยที่สุดที่พบ (เช่น `7`)
#
# | ตัวอย่าง Input | ตัวอย่าง Output |
# |---|---|
# | `4`<br>`25`<br>`12`<br>`38`<br>`7` | `7` |

# %%
# ตัวอย่าง 4.2.1: หาค่าน้อยที่สุด min_x จากข้อมูล n จำนวน
n = int(input())
min_x = int(input())
k = 0

# TODO

print(min_x)

# %% [markdown]
# ### ตัวอย่าง 4.2.2: การนับจำนวนเลข 0 จากข้อมูลที่แยกด้วย space
#
# **คำอธิบายโจทย์:**
# รับข้อความชุดตัวเลขที่คั่นด้วยช่องว่างในบรรทัดเดียว แล้วนับว่ามีเลข `0` อยู่ทั้งหมดกี่ตัว
#
# * **📥 ข้อมูลที่ต้องป้อน (Input):**
#   * สตริงชุดตัวเลขคั่นด้วยช่องว่าง 1 บรรทัด เช่น `10 20 3 0 3 0 43 0 3 20 0 2`
# * **📤 ข้อมูลส่งออก (Output):**
#   * จำนวนตัวเลข 0 ที่พบ (เช่น `4`)
#
# | ตัวอย่าง Input | ตัวอย่าง Output |
# |---|---|
# | `10 20 3 0 3 0 43 0 3 20 0 2` | `4` |

# %%
# ตัวอย่าง 4.2.2: นับจำนวนเลข 0 จากข้อมูลในบรรทัดเดียวกัน
x = input().split()
i = 0
c = 0

# TODO

print(c)

# %% [markdown]
# ### ตัวอย่าง 4.2.3: นับสระในข้อความ t โดยใช้ while loop
#
# **คำอธิบายโจทย์:**
# รับข้อความ `t` 1 บรรทัด แล้ววนลูปนับจำนวนสระภาษาอังกฤษ (`a, e, i, o, u` ทั้งตัวพิมพ์เล็กและตัวพิมพ์ใหญ่)
#
# * **📥 ข้อมูลที่ต้องป้อน (Input):**
#   * ข้อความสตริง 1 บรรทัด เช่น `University`
# * **📤 ข้อมูลส่งออก (Output):**
#   * จำนวนสระที่พบ (เช่น `5` ตัว คือ U, i, e, i)
#
# | ตัวอย่าง Input | ตัวอย่าง Output |
# |---|---|
# | `University` | `5` |
# | `Python` | `1` |

# %%
# ตัวอย่าง 4.2.3: อ่านข้อความ t เพื่อนับจำนวนสระ (ทั้งตัวเล็กและตัวใหญ่)
t = input()
c = 0
vowels = "aeiouAEIOU"
k = 0

# TODO

print(c)

# %% [markdown]
# ### แบบฝึกหัด 4-2 ข้อที่ 1: แสดงเลขคี่ตั้งแต่ 1 ถึง n
#
# **คำอธิบายโจทย์:**
# รับจำนวนเต็ม `n` จากผู้ใช้ แล้วแสดงจำนวนเต็มคี่ตั้งแต่ `1` ถึงจำนวนคี่ที่ไม่เกิน `n` บรรทัดละจำนวน (โดยใช้ลูป `while`)
#
# * **📥 ข้อมูลที่ต้องป้อน (Input):** จำนวนเต็ม `n` เช่น `9`
# * **📤 ข้อมูลส่งออก (Output):** เลขคี่ `1`, `3`, `5`, `7`, `9` แสดงแยกบรรทัดละตัว
#
# | ตัวอย่าง Input | ตัวอย่าง Output |
# |---|---|
# | `9` | `1`<br>`3`<br>`5`<br>`7`<br>`9` |
# | `4` | `1`<br>`3` |

# %%
# แบบฝึกหัด 4-2 ข้อที่ 1: แสดงเลขคี่ตั้งแต่ 1 ถึง n
n = int(input())
i = 1

# TODO

# %% [markdown]
# ### แบบฝึกหัด 4-2 ข้อที่ 2: หาผลรวมของข้อมูล n จำนวน
#
# **คำอธิบายโจทย์:**
# บรรทัดแรกรับจำนวนเต็ม `n` จากนั้นรับจำนวนเต็มเข้ามาอีก `n` บรรทัด ($d_0, d_1, \dots, d_{n-1}$) เพื่อหาผลรวมของตัวเลขทั้งหมด
#
# * **📥 ข้อมูลที่ต้องป้อน (Input):**
#   * บรรทัดที่ 1: จำนวนเต็ม `n` (เช่น `3`)
#   * บรรทัดถัดไป `n` บรรทัด: ตัวเลขแต่ละจำนวน (เช่น `10`, `20`, `30`)
# * **📤 ข้อมูลส่งออก (Output):**
#   * ผลรวมของตัวเลขทั้งหมด (เช่น `60`)
#
# | ตัวอย่าง Input | ตัวอย่าง Output |
# |---|---|
# | `3`<br>`10`<br>`20`<br>`30` | `60` |
# | `4`<br>`5`<br>`5`<br>`5`<br>`5` | `20` |

# %%
# แบบฝึกหัด 4-2 ข้อที่ 2: ผลรวมของข้อมูล n จำนวน
n = int(input())
k = 0
s = 0

# TODO

print(s)

# %% [markdown]
# ### แบบฝึกหัด 4-2 ข้อที่ 3: หาผลรวมจนกว่าจะพบจำนวนลบ
#
# **คำอธิบายโจทย์:**
# รับจำนวนเต็มเข้ามาทีละบรรทัดอย่างต่อเนื่องเพื่อหาผลรวมสะสม จนกระทั่งพบจำนวนลบ ($< 0$) จึงหยุดการรับข้อมูล (ไม่นำจำนวนลบมาบวกในผลรวม)
#
# * **📥 ข้อมูลที่ต้องป้อน (Input):**
#   * จำนวนเต็มบวกทีละบรรทัด และปิดท้ายด้วยจำนวนเต็มลบ (เช่น `5`, `12`, `8`, `-1`)
# * **📤 ข้อมูลส่งออก (Output):**
#   * ผลรวมของจำนวนเต็มบวกทั้งหมดก่อนเจอจำนวนลบ (เช่น `25`)
#
# | ตัวอย่าง Input | ตัวอย่าง Output |
# |---|---|
# | `5`<br>`12`<br>`8`<br>`-1` | `25` |
# | `100`<br>`-5` | `100` |

# %%
# แบบฝึกหัด 4-2 ข้อที่ 3: รับจำนวนเต็มจนกว่าจะพบจำนวนลบ
s = 0
x = int(input())

# TODO

print(s)

# %% [markdown]
# ### แบบฝึกหัด 4-2 ข้อที่ 4: หาผลรวมจนกว่าจะพบคำว่า "end"
#
# **คำอธิบายโจทย์:**
# รับข้อมูลเข้ามาทีละบรรทัดอย่างต่อเนื่องเพื่อหาผลรวมสะสม จนกระทั่งบรรทัดสุดท้ายเป็นข้อความว่า `"end"` จึงหยุดการทำงาน
#
# * **📥 ข้อมูลที่ต้องป้อน (Input):**
#   * ตัวเลขจำนวนเต็มทีละบรรทัด และปิดท้ายด้วยคำว่า `end` (เช่น `10`, `25`, `15`, `end`)
# * **📤 ข้อมูลส่งออก (Output):**
#   * ผลรวมของตัวเลขทั้งหมดก่อนหน้าคำว่า `end` (เช่น `50`)
#
# | ตัวอย่าง Input | ตัวอย่าง Output |
# |---|---|
# | `10`<br>`25`<br>`15`<br>`end` | `50` |
# | `end` | `0` |

# %%
# แบบฝึกหัด 4-2 ข้อที่ 4: รับจำนวนเต็มจนกว่าจะพบคำว่า "end"
s = 0
x = input()

# TODO

print(s)
