# %% [markdown]
# ---
#
# ## 4.5 for c in string (การวนซ้ำในสายอักขระ)
#
# ### อธิบายแนวคิด (Concept Explanation)
# ในภาษา Python ข้อความสตริง (String) เป็นข้อมูลประเภทลำดับ (Sequence) เราสามารถใช้คำสั่ง `for c in text:` เพื่อดึงตัวอักษรแต่ละตัวออกมาประมวลผลทีละตำแหน่งจากซ้ายไปขวาได้อย่างสะดวกรวดเร็ว

# %% [markdown]
# ### ตัวอย่าง: นับจำนวนสระภาษาอังกฤษในข้อความ
#
# **คำอธิบายโจทย์:**
# วนลูปทีละตัวอักษรใน `text` เพื่อนับว่ามีสระภาษาอังกฤษ (`aeiouAEIOU`) ทั้งหมดกี่ตัว
#
# * **ข้อมูลนำเข้า (Input):** กำหนด `text = "Python Programming"`
# * **ข้อมูลส่งออก (Output):** จำนวนสระที่พบ (เช่น `4` ตัว)

# %%
# ตัวอย่าง: นับจำนวนสระภาษาอังกฤษในข้อความ
text = "Python Programming"
vowel_count = 0

# TODO

print(f"พบสระทั้งหมด {vowel_count} ตัว")

# %% [markdown]
# ### ตัวอย่าง 4.5.1: นับจำนวนตัวเลข 0 ถึง 9 ในสตริง
#
# **คำอธิบายโจทย์:**
# รับข้อความ `t` จากผู้ใช้ แล้วนับว่ามีอักขระที่เป็นตัวเลขโดด (`0-9`) อยู่กี่ตัว
#
# * **ข้อมูลที่ต้องป้อน (Input):** ข้อความ 1 บรรทัด เช่น `Python 3.10 and 2026`
# * **ข้อมูลส่งออก (Output):** จำนวนตัวเลขโดดที่พบ (เช่น `7` ตัว)
#
# | ตัวอย่าง Input | ตัวอย่าง Output |
# |---|---|
# | `Python 3.10 and 2026` | `7` |
# | `Hello World` | `0` |

# %%
# ตัวอย่าง 4.5.1: นับจำนวนตัวเลข 0 ถึง 9 ในสตริง
t = input()
s = 0

# TODO

print(s)

# %% [markdown]
# ### ตัวอย่าง 4.5.2: การแทนที่เครื่องหมายวรรคตอนด้วยช่องว่าง
#
# **คำอธิบายโจทย์:**
# รับข้อความ `t` แล้วสร้างข้อความใหม่โดยเปลี่ยนเครื่องหมาย `.` `,` `(` `)` ให้กลายเป็นช่องว่าง `' '`
#
# * **ข้อมูลที่ต้องป้อน (Input):** ข้อความ 1 บรรทัด เช่น `(Hello, World.)`
# * **ข้อมูลส่งออก (Output):** ข้อความหลังแทนที่เครื่องหมายด้วยช่องว่าง (เช่น ` Hello  World  `)
#
# | ตัวอย่าง Input | ตัวอย่าง Output |
# |---|---|
# | `(Hello, World.)` | ` Hello  World  ` |

# %%
# ตัวอย่าง 4.5.2: เปลี่ยนสัญลักษณ์ .,() เป็นช่องว่าง
t = input()
s = ""

# TODO

print(s)

# %% [markdown]
# ### ตัวอย่าง 4.5.3: แสดงเฉพาะตัวอักษรภาษาอังกฤษ
#
# **คำอธิบายโจทย์:**
# รับข้อความ `t` แล้วกรองแสดงเฉพาะตัวอักษรภาษาอังกฤษ (`a-z` หรือ `A-Z`) ออกมาทีละบรรทัด
#
# * **ข้อมูลที่ต้องป้อน (Input):** ข้อความ 1 บรรทัด เช่น `Python 101!`
# * **ข้อมูลส่งออก (Output):** ตัวอักษร `P, y, t, h, o, n` แยกบรรทัดละตัว
#
# | ตัวอย่าง Input | ตัวอย่าง Output |
# |---|---|
# | `Python 101!` | `P`<br>`y`<br>`t`<br>`h`<br>`o`<br>`n` |

# %%
# ตัวอย่าง 4.5.3: แสดงเฉพาะตัวอักษรภาษาอังกฤษ
t = input()

# TODO

# %% [markdown]
# ### ตัวอย่าง 4.5.4: แสดงเฉพาะอักขระที่ตำแหน่ง Index คี่
#
# **คำอธิบายโจทย์:**
# รับข้อความ `t` แล้วใช้ Slicing `t[1::2]` เพื่อดึงเฉพาะอักขระในตำแหน่งดัชนีคี่ (1, 3, 5, ...) ออกมาแสดงทีละบรรทัด
#
# * **ข้อมูลที่ต้องป้อน (Input):** ข้อความ 1 บรรทัด เช่น `ABCDEF`
# * **ข้อมูลส่งออก (Output):** ตัวอักษร `B`, `D`, `F`
#
# | ตัวอย่าง Input | ตัวอย่าง Output |
# |---|---|
# | `ABCDEF` | `B`<br>`D`<br>`F` |

# %%
# ตัวอย่าง 4.5.4: แสดงเฉพาะอักขระที่ Index คี่
t = input()

# TODO
