# %% [markdown]
# # Module 9: Lab Exercises (แบบฝึกหัดเรื่อง โครงสร้างแบบซ้อน)
#
# ---

# %% [markdown]
# ### แบบฝึกหัด 9-1 ข้อที่ 1: ตารางสูตรคูณแม่ 2 ถึง N ชิดขวาความกว้าง 4 ช่อง (while loop)
# **โจทย์:** จงเขียนโปรแกรมรับ N แล้วแสดงตารางสูตรคูณของแม่ 2 จนถึงแม่ N (คูณ 1 ถึง 5) โดยใช้เฉพาะคำสั่ง `while` (ห้ามใช้ `for`)

# %%
def left_pad(n, k):
    return (" " * k + str(n))[-k:]

# %% [markdown]
# ### แบบฝึกหัด 9-1 ข้อที่ 2: ตะแกรงร่อนจำนวนเฉพาะ Sieve of Eratosthenes (while loop)
# **โจทย์:** เขียนโปรแกรมตามผังงาน Sieve of Eratosthenes โดยใช้เฉพาะคำสั่ง `while` (ห้ามใช้ `for`)

# %%
N = int(input())
prime = [True] * (N + 1)

# TODO

# %% [markdown]
# ### แบบฝึกหัด 9-2 ข้อที่ 1: รายการแข่งขันฟุตบอลแบบพบกันหมด (for loop)
# **โจทย์:** จงเขียนโปรแกรมอ่านรายการของชื่อโรงเรียน เพื่อแสดงรายการการแข่งขันฟุตบอลแบบพบกันหมด โดยแสดงบรรทัดละคู่ เรียงตามพจนานุกรม

# %%
schools = input().split()

# TODO

# %% [markdown]
# ### แบบฝึกหัด 9-2 ข้อที่ 2: ตารางสูตรคูณแม่ 2 ถึง N ชิดขวาความกว้าง 4 ช่อง (for loop)
# **โจทย์:** จงเขียนโปรแกรมรับ N แล้วแสดงตารางสูตรคูณของแม่ 2 จนถึงแม่ N (คูณ 1 ถึง 5) โดยใช้เฉพาะคำสั่ง `for` (ห้ามใช้ `while`)

# %%
def left_pad(n, k):
    return (" " * k + str(n))[-k:]

# %% [markdown]
# ### แบบฝึกหัด 9-3 ข้อที่ 1: การนับตัวเลขโดดโดยแยกลูปออกเป็นฟังก์ชันย่อย
# **โจทย์:** ฟังก์ชัน `count_digit(x, d)` คืนจำนวนเลขโดด `d` ที่ปรากฏในลิสต์ของจำนวนเต็ม `x` โดยไม่มีวงวนซ้อนกัน

# %%
def count(n, d):
    # TODO
    pass

def count_digit(x, d):
    # TODO
    pass

# %% [markdown]
# ### แบบฝึกหัด 9-3 ข้อที่ 2: ฟังก์ชันหาคำลงท้ายยาวสุด (longest_suffix)
# **โจทย์:** จงเขียนฟังก์ชัน `longest_suffix(words)` คืนสตริงที่ยาวที่สุดที่ปรากฏเป็นส่วนท้ายของทุกสตริงใน `words`

# %%
def longest_suffix(words):
    # TODO
    pass

# %% [markdown]
# ### แบบฝึกหัด 9-3 ข้อที่ 3: Lychrel Number ที่น้อยที่สุดที่มากกว่า N
# **โจทย์:** รับจำนวนเต็ม N แสดง Lychrel number ที่น้อยที่สุดที่มากกว่า N

# %%
def reverse_and_add(n):
    # TODO
    pass

def is_palindrome(n):
    # TODO
    pass

# %% [markdown]
# ### แบบฝึกหัด 9-4 ข้อที่ 1: แยกตัวเลขลงถังตามหลักหน่วย (to_buckets)
# **โจทย์:** เขียนฟังก์ชัน `to_buckets(d)` รับลิสต์จำนวนเต็ม คืนลิสต์ 10 ช่อง ช่องที่ k เก็บจำนวนที่มีหลักหน่วยเป็น k

# %%
def to_buckets(d):
    # TODO
    pass

# %% [markdown]
# ### แบบฝึกหัด 9-4 ข้อที่ 2: อ่านพิกัดจุดจากอินพุต (read_points)
# **โจทย์:** อ่านอินพุต `x0:y0, x1:y1, ...` คืนลิสต์พิกัด `[[x0, y0], [x1, y1], ...]`

# %%
def read_points():
    # TODO
    pass

# %% [markdown]
# ### แบบฝึกหัด 9-4 ข้อที่ 3: หาคู่จุดที่อยู่ใกล้กันที่สุดทั้งหมด (all_closest_pairs)
# **โจทย์:** รับลิสต์พิกัดจุด คืนลิสต์ดัชนีของคู่จุดที่ใกล้ที่สุดทั้งหมดเรียงจากน้อยไปมาก

# %%
def distance(p1, p2):
    # TODO
    pass

def all_closest_pairs(points):
    # TODO
    pass

# %% [markdown]
# ### แบบฝึกหัด 9-4 ข้อที่ 4: แปลงลิสต์คู่การชื่นชอบเป็น Dictionary (to_dict)
# **โจทย์:** แปลงลิสต์ `[[u1, u2], ...]` เป็น Dictionary `{user: [ลิสต์คนที่ user ชอบ]}`

# %%
def to_dict(like_list):
    # TODO
    pass

# %% [markdown]
# ### แบบฝึกหัด 9-5 ข้อที่ 1: ผลรวมของทุกจำนวนในเมทริกซ์ (sum_all)
# **โจทย์:** คืนผลรวมของทุกสมาชิกในเมทริกซ์ `M`

# %%
def sum_all(M):
    # TODO
    pass

# %% [markdown]
# ### แบบฝึกหัด 9-5 ข้อที่ 2: ผลรวมในแต่ละแถวแนวนอน (sum_row)
# **โจทย์:** คืนลิสต์เก็บผลรวมในแต่ละแถวแนวนอนของเมทริกซ์ `M`

# %%
def sum_row(M):
    # TODO
    pass

# %% [markdown]
# ### แบบฝึกหัด 9-5 ข้อที่ 3: ผลรวมในแต่ละหลักแนวตั้ง (sum_col)
# **โจทย์:** คืนลิสต์เก็บผลรวมในแต่ละหลักแนวตั้งของเมทริกซ์ `M`

# %%
def sum_col(M):
    # TODO
    pass

# %% [markdown]
# ### แบบฝึกหัด 9-5 ข้อที่ 4: สร้างเมทริกซ์เอกลักษณ์ (identity)
# **โจทย์:** รับ `n` คืนเมทริกซ์เอกลักษณ์ขนาด `n x n`

# %%
def identity(n):
    # TODO
    pass

# %% [markdown]
# ### แบบฝึกหัด 9-6 ข้อที่ 1: การบวกเวกเตอร์ด้วย List Comprehension (add)
# **โจทย์:** คืนลิสต์ผลบวกของสองเวกเตอร์โดยใช้ list comprehension บรรทัดเดียว

# %%
def add(u, v):
    # TODO
    pass

# %% [markdown]
# ### แบบฝึกหัด 9-6 ข้อที่ 2: คำนวณ Dot Product ด้วย List Comprehension (dot)
# **โจทย์:** คืนค่า dot product ของสองเวกเตอร์โดยใช้ list comprehension บรรทัดเดียวร่วมกับ `sum()`

# %%
def dot(u, v):
    # TODO
    pass

# %% [markdown]
# ### แบบฝึกหัด 9-6 ข้อที่ 3: แปลงสมาชิกในลิสต์เป็นสตริง (to_list_of_strings)
# **โจทย์:** แปลงสมาชิกทุกตัวในลิสต์เป็นสตริงโดยใช้ list comprehension บรรทัดเดียว

# %%
def to_list_of_strings(x):
    # TODO
    pass

# %% [markdown]
# ### แบบฝึกหัด 9-6 ข้อที่ 4: คัดเลือกเฉพาะจำนวนบวก (get_positive)
# **โจทย์:** คืนลิสต์ใหม่ที่มีเฉพาะจำนวนบวก (`e > 0`) โดยใช้ list comprehension บรรทัดเดียว

# %%
def get_positive(x):
    # TODO
    pass
